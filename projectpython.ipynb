# %%
import matplotlib.pyplot as plt

causes=["Fossil Fuels","Deforestation","Industry","Vehicles"]
impact_Level=[40,25,20,15]
plt.bar(causes,impact_Level)

plt.xlabel("Causes of Climate Change")
plt.ylabel("Impact Percentage")
plt.title("Sustainable Development Goals: Climate Change Causes")
plt.show()
